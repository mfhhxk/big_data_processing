# %% [markdown]
# # 1. Producing the data
# In this task, we will implement one Apache Kafka producer to simulate real-time data streaming. Spark is not allowed in this part since it’s simulating a streaming data source.
#
# 1.1 Your program should send one batch of click_stream data every 5 seconds. One batch consists of a random 500-1000 rows from the clickstream_rt dataset. The CSV shouldn’t be loaded to memory at once to conserve memory (i.e. Read row as needed).
# 1.2 For each row, add an integer column named ‘ts’, a Unix timestamp in seconds since the epoch (UTC timezone). Spead your batch out evenly for 5 seconds.
# For example, if you send a batch of 600 records at 2023-09-01 00:00:00 (ISO format: YYYY-MM-DD HH:MM:SS) -> (ts = 1693526400) :
# Record 1-120: ts = 1693526400
# Record 121-240: ts = 1693526401
# Record 241-360: ts = 1693526402
# ….
# 1.3 Send your batch to a Kafka topic with an appropriate name.
#
# All the data except for the ‘ts’ column should be sent in the original String type, without changing to any other types.

# %%
from time import sleep
from kafka3 import KafkaProducer
import random
import datetime as dt
import csv

# Configuration
hostip = "118.138.83.246"  # Change me



def read_csv_batch(file_name, batch_size):
    with open(file_name, 'rt') as f:
        reader = csv.DictReader(f)
        batch = []
        for row in reader:
            batch.append(row)
            
            # if reach the specified batch size 
            # yield a seq of batch then clear the list
            if len(batch) >= batch_size:
                yield batch
                batch = []

        # yield if not empty list
        if batch:
            yield batch

def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(str(value), encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
#         print(data)
        
#         for i, record in enumerate(value):
#             value_str = str(record)
#             value_bytes = bytes(value_str, encoding='utf-8')
#             print(value)
#             producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
#             print(f'Record {i + 1} published successfully. ts = {timestamp + i}')
        
        # evenly spread out of 5s
#         record_per_second = total_records//5
#         producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        
        # printing message
#         print(f'Batch published successfully. Number of records: {total_records}')
#         print(f'- Record 1-{record_per_second}: ts = {timestamp}')
#         print(f'- Record {record_per_second+1}-{2*record_per_second}: ts = {timestamp+1}')
#         print(f'- Record {2*record_per_second+1}-{3*record_per_second}: ts = {timestamp+2}')
#         print(f'- Record {3*record_per_second+1}-{4*record_per_second}: ts = {timestamp+3}')
#         print(f'- Record {4*record_per_second+1}-{total_records}: ts = {timestamp+4}')
# #         print(value)
    
    except Exception as ex:
        print('Exception in publishing batch.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'], 
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
    
if __name__ == '__main__':
    # setting topic name
    # & reading file
    topic = 'clickstream_realtime'
    csv_file = 'click_stream_rt.csv'

    print('Publishing records..')
    
    # connect to kafka producer
    producer = connect_kafka_producer()
    
    while True:
        # random size of batch: 500 to 1000
        batch_size = random.randint(500, 1000)
        
        # unix timestamp
        timestamp = int(dt.datetime.now().timestamp())
        
        # random draw of sample to form a batch with size of batch_size
        batch = random.sample(list(read_csv_batch(csv_file, batch_size)), 1)[0]  
        total_records = len(batch)
#         print(batch)
        lst = []
        record_per_second = total_records//5
        
        # loop thr each record in the batch
        for i, record in enumerate(batch):
#             # finding ts of each batch
#             record['ts'] = timestamp + i
            if i in range(0,record_per_second-1):
                record['ts'] = timestamp 
            elif i in range(record_per_second,2*record_per_second-1):
                record['ts'] = timestamp +1
            elif i in range(2*record_per_second,3*record_per_second-1):
                record['ts'] = timestamp +2
            elif i in range(3*record_per_second,4*record_per_second-1):
                record['ts'] = timestamp +3
            else: 
                record['ts'] = timestamp +4
                
                
            # value = data ie each row info
            data = {'session_id': record['session_id'],
                    'event_name': record['event_name'],
                    'event_id': record['event_id'],
                    'customer_id': record['customer_id'],
                    'event_metadata':record['event_metadata'],
                    'customer_id':record['customer_id'],
                    'ts': record['ts']}
            lst.append(data)
            publish_message(producer, topic, 'parsed', data)
#         print(lst)
        record_per_second = total_records//5
        print(f'Batch published successfully. Number of records: {total_records}')
        print(f'- Record 1-{record_per_second}: ts = {timestamp}')
        print(f'- Record {record_per_second+1}-{2*record_per_second}: ts = {timestamp+1}')
        print(f'- Record {2*record_per_second+1}-{3*record_per_second}: ts = {timestamp+2}')
        print(f'- Record {3*record_per_second+1}-{4*record_per_second}: ts = {timestamp+3}')
        print(f'- Record {4*record_per_second+1}-{total_records}: ts = {timestamp+4}')

        sleep(5)
# Out:
# Publishing records..
# Batch published successfully. Number of records: 991
# - Record 1-198: ts = 1697770945
# - Record 199-396: ts = 1697770946
# - Record 397-594: ts = 1697770947
# - Record 595-792: ts = 1697770948
# - Record 793-991: ts = 1697770949
# Batch published successfully. Number of records: 678
# - Record 1-135: ts = 1697770952
# - Record 136-270: ts = 1697770953
# - Record 271-405: ts = 1697770954
# - Record 406-540: ts = 1697770955
# - Record 541-678: ts = 1697770956
# Batch published successfully. Number of records: 793
# - Record 1-158: ts = 1697770959
# - Record 159-316: ts = 1697770960
# - Record 317-474: ts = 1697770961
# - Record 475-632: ts = 1697770962
# - Record 633-793: ts = 1697770963
# Batch published successfully. Number of records: 935
# - Record 1-187: ts = 1697770966
# - Record 188-374: ts = 1697770967
# - Record 375-561: ts = 1697770968
# - Record 562-748: ts = 1697770969
# - Record 749-935: ts = 1697770970
# Batch published successfully. Number of records: 742
# - Record 1-148: ts = 1697770972
# - Record 149-296: ts = 1697770973
# - Record 297-444: ts = 1697770974
# - Record 445-592: ts = 1697770975
# - Record 593-742: ts = 1697770976
# Batch published successfully. Number of records: 674
# - Record 1-134: ts = 1697770979
# - Record 135-268: ts = 1697770980
# - Record 269-402: ts = 1697770981
# - Record 403-536: ts = 1697770982
# - Record 537-674: ts = 1697770983
# Batch published successfully. Number of records: 935
# - Record 1-187: ts = 1697770985
# - Record 188-374: ts = 1697770986
# - Record 375-561: ts = 1697770987
# - Record 562-748: ts = 1697770988
# - Record 749-935: ts = 1697770989
# Batch published successfully. Number of records: 747
# - Record 1-149: ts = 1697770991
# - Record 150-298: ts = 1697770992
# - Record 299-447: ts = 1697770993
# - Record 448-596: ts = 1697770994
# - Record 597-747: ts = 1697770995
# Batch published successfully. Number of records: 825
# - Record 1-165: ts = 1697770998
# - Record 166-330: ts = 1697770999
# - Record 331-495: ts = 1697771000
# - Record 496-660: ts = 1697771001
# - Record 661-825: ts = 1697771002
# Batch published successfully. Number of records: 504
# - Record 1-100: ts = 1697771004
# - Record 101-200: ts = 1697771005
# - Record 201-300: ts = 1697771006
# - Record 301-400: ts = 1697771007
# - Record 401-504: ts = 1697771008
# Batch published successfully. Number of records: 980
# - Record 1-196: ts = 1697771011
# - Record 197-392: ts = 1697771012
# - Record 393-588: ts = 1697771013
# - Record 589-784: ts = 1697771014
# - Record 785-980: ts = 1697771015
# Batch published successfully. Number of records: 586
# - Record 1-117: ts = 1697771017
# - Record 118-234: ts = 1697771018
# - Record 235-351: ts = 1697771019
# - Record 352-468: ts = 1697771020
# - Record 469-586: ts = 1697771021
# Batch published successfully. Number of records: 992
# - Record 1-198: ts = 1697771023
# - Record 199-396: ts = 1697771024
# - Record 397-594: ts = 1697771025
# - Record 595-792: ts = 1697771026
# - Record 793-992: ts = 1697771027
# Batch published successfully. Number of records: 858
# - Record 1-171: ts = 1697771030
# - Record 172-342: ts = 1697771031
# - Record 343-513: ts = 1697771032
# - Record 514-684: ts = 1697771033
# - Record 685-858: ts = 1697771034
# Batch published successfully. Number of records: 599
# - Record 1-119: ts = 1697771036
# - Record 120-238: ts = 1697771037
# - Record 239-357: ts = 1697771038
# - Record 358-476: ts = 1697771039
# - Record 477-599: ts = 1697771040
# Batch published successfully. Number of records: 918
# - Record 1-183: ts = 1697771043
# - Record 184-366: ts = 1697771044
# - Record 367-549: ts = 1697771045
# - Record 550-732: ts = 1697771046
# - Record 733-918: ts = 1697771047
# Batch published successfully. Number of records: 875
# - Record 1-175: ts = 1697771049
# - Record 176-350: ts = 1697771050
# - Record 351-525: ts = 1697771051
# - Record 526-700: ts = 1697771052
# - Record 701-875: ts = 1697771053
# Batch published successfully. Number of records: 830
# - Record 1-166: ts = 1697771056
# - Record 167-332: ts = 1697771057
# - Record 333-498: ts = 1697771058
# - Record 499-664: ts = 1697771059
# - Record 665-830: ts = 1697771060
# Batch published successfully. Number of records: 753
# - Record 1-150: ts = 1697771062
# - Record 151-300: ts = 1697771063
# - Record 301-450: ts = 1697771064
# - Record 451-600: ts = 1697771065
# - Record 601-753: ts = 1697771066
# Batch published successfully. Number of records: 546
# - Record 1-109: ts = 1697771068
# - Record 110-218: ts = 1697771069
# - Record 219-327: ts = 1697771070
# - Record 328-436: ts = 1697771071
# - Record 437-546: ts = 1697771072
# Batch published successfully. Number of records: 744
# - Record 1-148: ts = 1697771075
# - Record 149-296: ts = 1697771076
# - Record 297-444: ts = 1697771077
# - Record 445-592: ts = 1697771078
# - Record 593-744: ts = 1697771079
# Batch published successfully. Number of records: 946
# - Record 1-189: ts = 1697771081
# - Record 190-378: ts = 1697771082
# - Record 379-567: ts = 1697771083
# - Record 568-756: ts = 1697771084
# - Record 757-946: ts = 1697771085
# Batch published successfully. Number of records: 661
# - Record 1-132: ts = 1697771087
# - Record 133-264: ts = 1697771088
# - Record 265-396: ts = 1697771089
# - Record 397-528: ts = 1697771090
# - Record 529-661: ts = 1697771091
# Batch published successfully. Number of records: 685
# - Record 1-137: ts = 1697771094
# - Record 138-274: ts = 1697771095
# - Record 275-411: ts = 1697771096
# - Record 412-548: ts = 1697771097
# - Record 549-685: ts = 1697771098
# Batch published successfully. Number of records: 885
# - Record 1-177: ts = 1697771100
# - Record 178-354: ts = 1697771101
# - Record 355-531: ts = 1697771102
# - Record 532-708: ts = 1697771103
# - Record 709-885: ts = 1697771104
# Batch published successfully. Number of records: 892
# - Record 1-178: ts = 1697771106
# - Record 179-356: ts = 1697771107
# - Record 357-534: ts = 1697771108
# - Record 535-712: ts = 1697771109
# - Record 713-892: ts = 1697771110
# Batch published successfully. Number of records: 699
# - Record 1-139: ts = 1697771113
# - Record 140-278: ts = 1697771114
# - Record 279-417: ts = 1697771115
# - Record 418-556: ts = 1697771116
# - Record 557-699: ts = 1697771117
# Batch published successfully. Number of records: 735
# - Record 1-147: ts = 1697771119
# - Record 148-294: ts = 1697771120
# - Record 295-441: ts = 1697771121
# - Record 442-588: ts = 1697771122
# - Record 589-735: ts = 1697771123
# Batch published successfully. Number of records: 714
# - Record 1-142: ts = 1697771125
# - Record 143-284: ts = 1697771126
# - Record 285-426: ts = 1697771127
# - Record 427-568: ts = 1697771128
# - Record 569-714: ts = 1697771129
# Batch published successfully. Number of records: 593
# - Record 1-118: ts = 1697771132
# - Record 119-236: ts = 1697771133
# - Record 237-354: ts = 1697771134
# - Record 355-472: ts = 1697771135
# - Record 473-593: ts = 1697771136
# Batch published successfully. Number of records: 674
# - Record 1-134: ts = 1697771138
# - Record 135-268: ts = 1697771139
# - Record 269-402: ts = 1697771140
# - Record 403-536: ts = 1697771141
# - Record 537-674: ts = 1697771142
# Batch published successfully. Number of records: 581
# - Record 1-116: ts = 1697771144
# - Record 117-232: ts = 1697771145
# - Record 233-348: ts = 1697771146
# - Record 349-464: ts = 1697771147
# - Record 465-581: ts = 1697771148
# Batch published successfully. Number of records: 891
# - Record 1-178: ts = 1697771150
# - Record 179-356: ts = 1697771151
# - Record 357-534: ts = 1697771152
# - Record 535-712: ts = 1697771153
# - Record 713-891: ts = 1697771154
# Batch published successfully. Number of records: 583
# - Record 1-116: ts = 1697771157
# - Record 117-232: ts = 1697771158
# - Record 233-348: ts = 1697771159
# - Record 349-464: ts = 1697771160
# - Record 465-583: ts = 1697771161
# Batch published successfully. Number of records: 737
# - Record 1-147: ts = 1697771163
# - Record 148-294: ts = 1697771164
# - Record 295-441: ts = 1697771165
# - Record 442-588: ts = 1697771166
# - Record 589-737: ts = 1697771167
# Batch published successfully. Number of records: 987
# - Record 1-197: ts = 1697771169
# - Record 198-394: ts = 1697771170
# - Record 395-591: ts = 1697771171
# - Record 592-788: ts = 1697771172
# - Record 789-987: ts = 1697771173
# Batch published successfully. Number of records: 783
# - Record 1-156: ts = 1697771176
# - Record 157-312: ts = 1697771177
# - Record 313-468: ts = 1697771178
# - Record 469-624: ts = 1697771179
# - Record 625-783: ts = 1697771180
# Batch published successfully. Number of records: 532
# - Record 1-106: ts = 1697771182
# - Record 107-212: ts = 1697771183
# - Record 213-318: ts = 1697771184
# - Record 319-424: ts = 1697771185
# - Record 425-532: ts = 1697771186
# Batch published successfully. Number of records: 808
# - Record 1-161: ts = 1697771188
# - Record 162-322: ts = 1697771189
# - Record 323-483: ts = 1697771190
# - Record 484-644: ts = 1697771191
# - Record 645-808: ts = 1697771192
# Batch published successfully. Number of records: 755
# - Record 1-151: ts = 1697771195
# - Record 152-302: ts = 1697771196
# - Record 303-453: ts = 1697771197
# - Record 454-604: ts = 1697771198
# - Record 605-755: ts = 1697771199
# Batch published successfully. Number of records: 749
# - Record 1-149: ts = 1697771201
# - Record 150-298: ts = 1697771202
# - Record 299-447: ts = 1697771203
# - Record 448-596: ts = 1697771204
# - Record 597-749: ts = 1697771205
# Batch published successfully. Number of records: 695
# - Record 1-139: ts = 1697771207
# - Record 140-278: ts = 1697771208
# - Record 279-417: ts = 1697771209
# - Record 418-556: ts = 1697771210
# - Record 557-695: ts = 1697771211
# Batch published successfully. Number of records: 895
# - Record 1-179: ts = 1697771214
# - Record 180-358: ts = 1697771215
# - Record 359-537: ts = 1697771216
# - Record 538-716: ts = 1697771217
# - Record 717-895: ts = 1697771218
# Batch published successfully. Number of records: 692
# - Record 1-138: ts = 1697771220
# - Record 139-276: ts = 1697771221
# - Record 277-414: ts = 1697771222
# - Record 415-552: ts = 1697771223
# - Record 553-692: ts = 1697771224
# Batch published successfully. Number of records: 763
# - Record 1-152: ts = 1697771231
# - Record 153-304: ts = 1697771232
# - Record 305-456: ts = 1697771233
# - Record 457-608: ts = 1697771234
# - Record 609-763: ts = 1697771235
# Batch published successfully. Number of records: 583
# - Record 1-116: ts = 1697771265
# - Record 117-232: ts = 1697771266
# - Record 233-348: ts = 1697771267
# - Record 349-464: ts = 1697771268
# - Record 465-583: ts = 1697771269
# Batch published successfully. Number of records: 684
# - Record 1-136: ts = 1697771271
# - Record 137-272: ts = 1697771272
# - Record 273-408: ts = 1697771273
# - Record 409-544: ts = 1697771274
# - Record 545-684: ts = 1697771275
# Batch published successfully. Number of records: 880
# - Record 1-176: ts = 1697771278
# - Record 177-352: ts = 1697771279
# - Record 353-528: ts = 1697771280
# - Record 529-704: ts = 1697771281
# - Record 705-880: ts = 1697771282
# Batch published successfully. Number of records: 795
# - Record 1-159: ts = 1697771289
# - Record 160-318: ts = 1697771290
# - Record 319-477: ts = 1697771291
# - Record 478-636: ts = 1697771292
# - Record 637-795: ts = 1697771293
# Batch published successfully. Number of records: 752
# - Record 1-150: ts = 1697771379
# - Record 151-300: ts = 1697771380
# - Record 301-450: ts = 1697771381
# - Record 451-600: ts = 1697771382
# - Record 601-752: ts = 1697771383
# Batch published successfully. Number of records: 881
# - Record 1-176: ts = 1697771385
# - Record 177-352: ts = 1697771386
# - Record 353-528: ts = 1697771387
# - Record 529-704: ts = 1697771388
# - Record 705-881: ts = 1697771389
# Batch published successfully. Number of records: 945
# - Record 1-189: ts = 1697771392
# - Record 190-378: ts = 1697771393
# - Record 379-567: ts = 1697771394
# - Record 568-756: ts = 1697771395
# - Record 757-945: ts = 1697771396
# Batch published successfully. Number of records: 512
# - Record 1-102: ts = 1697771398
# - Record 103-204: ts = 1697771399
# - Record 205-306: ts = 1697771400
# - Record 307-408: ts = 1697771401
# - Record 409-512: ts = 1697771402
# Batch published successfully. Number of records: 905
# - Record 1-181: ts = 1697771404
# - Record 182-362: ts = 1697771405
# - Record 363-543: ts = 1697771406
# - Record 544-724: ts = 1697771407
# - Record 725-905: ts = 1697771408
# Batch published successfully. Number of records: 624
# - Record 1-124: ts = 1697771411
# - Record 125-248: ts = 1697771412
# - Record 249-372: ts = 1697771413
# - Record 373-496: ts = 1697771414
# - Record 497-624: ts = 1697771415
# <BrokerConnection node_id=1 host=118.138.83.246:9092 <connected> [IPv4 ('118.138.83.246', 9092)]> timed out after 30000 ms. Closing connection.
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Batch published successfully. Number of records: 974
# - Record 1-194: ts = 1697771417
# - Record 195-388: ts = 1697771418
# - Record 389-582: ts = 1697771419
# - Record 583-776: ts = 1697771420
# - Record 777-974: ts = 1697771421
# Batch published successfully. Number of records: 545
# - Record 1-109: ts = 1697773282
# - Record 110-218: ts = 1697773283
# - Record 219-327: ts = 1697773284
# - Record 328-436: ts = 1697773285
# - Record 437-545: ts = 1697773286
# Batch published successfully. Number of records: 675
# - Record 1-135: ts = 1697773329
# - Record 136-270: ts = 1697773330
# - Record 271-405: ts = 1697773331
# - Record 406-540: ts = 1697773332
# - Record 541-675: ts = 1697773333
# Batch published successfully. Number of records: 581
# - Record 1-116: ts = 1697773335
# - Record 117-232: ts = 1697773336
# - Record 233-348: ts = 1697773337
# - Record 349-464: ts = 1697773338
# - Record 465-581: ts = 1697773339
# Batch published successfully. Number of records: 810
# - Record 1-162: ts = 1697773341
# - Record 163-324: ts = 1697773342
# - Record 325-486: ts = 1697773343
# - Record 487-648: ts = 1697773344
# - Record 649-810: ts = 1697773345
# Batch published successfully. Number of records: 779
# - Record 1-155: ts = 1697773348
# - Record 156-310: ts = 1697773349
# - Record 311-465: ts = 1697773350
# - Record 466-620: ts = 1697773351
# - Record 621-779: ts = 1697773352
# Batch published successfully. Number of records: 551
# - Record 1-110: ts = 1697773354
# - Record 111-220: ts = 1697773355
# - Record 221-330: ts = 1697773356
# - Record 331-440: ts = 1697773357
# - Record 441-551: ts = 1697773358
# Batch published successfully. Number of records: 780
# - Record 1-156: ts = 1697773360
# - Record 157-312: ts = 1697773361
# - Record 313-468: ts = 1697773362
# - Record 469-624: ts = 1697773363
# - Record 625-780: ts = 1697773364
# Batch published successfully. Number of records: 664
# - Record 1-132: ts = 1697773367
# - Record 133-264: ts = 1697773368
# - Record 265-396: ts = 1697773369
# - Record 397-528: ts = 1697773370
# - Record 529-664: ts = 1697773371
# Batch published successfully. Number of records: 539
# - Record 1-107: ts = 1697773373
# - Record 108-214: ts = 1697773374
# - Record 215-321: ts = 1697773375
# - Record 322-428: ts = 1697773376
# - Record 429-539: ts = 1697773377
# Batch published successfully. Number of records: 674
# - Record 1-134: ts = 1697773379
# - Record 135-268: ts = 1697773380
# - Record 269-402: ts = 1697773381
# - Record 403-536: ts = 1697773382
# - Record 537-674: ts = 1697773383
# Batch published successfully. Number of records: 839
# - Record 1-167: ts = 1697773385
# - Record 168-334: ts = 1697773386
# - Record 335-501: ts = 1697773387
# - Record 502-668: ts = 1697773388
# - Record 669-839: ts = 1697773389
# Batch published successfully. Number of records: 567
# - Record 1-113: ts = 1697773392
# - Record 114-226: ts = 1697773393
# - Record 227-339: ts = 1697773394
# - Record 340-452: ts = 1697773395
# - Record 453-567: ts = 1697773396
# Batch published successfully. Number of records: 754
# - Record 1-150: ts = 1697773398
# - Record 151-300: ts = 1697773399
# - Record 301-450: ts = 1697773400
# - Record 451-600: ts = 1697773401
# - Record 601-754: ts = 1697773402
# Batch published successfully. Number of records: 910
# - Record 1-182: ts = 1697773404
# - Record 183-364: ts = 1697773405
# - Record 365-546: ts = 1697773406
# - Record 547-728: ts = 1697773407
# - Record 729-910: ts = 1697773408
# Batch published successfully. Number of records: 965
# - Record 1-193: ts = 1697773411
# - Record 194-386: ts = 1697773412
# - Record 387-579: ts = 1697773413
# - Record 580-772: ts = 1697773414
# - Record 773-965: ts = 1697773415
# Batch published successfully. Number of records: 798
# - Record 1-159: ts = 1697773417
# - Record 160-318: ts = 1697773418
# - Record 319-477: ts = 1697773419
# - Record 478-636: ts = 1697773420
# - Record 637-798: ts = 1697773421
# Batch published successfully. Number of records: 677
# - Record 1-135: ts = 1697773423
# - Record 136-270: ts = 1697773424
# - Record 271-405: ts = 1697773425
# - Record 406-540: ts = 1697773426
# - Record 541-677: ts = 1697773427
# Batch published successfully. Number of records: 797
# - Record 1-159: ts = 1697773430
# - Record 160-318: ts = 1697773431
# - Record 319-477: ts = 1697773432
# - Record 478-636: ts = 1697773433
# - Record 637-797: ts = 1697773434
# Batch published successfully. Number of records: 824
# - Record 1-164: ts = 1697773436
# - Record 165-328: ts = 1697773437
# - Record 329-492: ts = 1697773438
# - Record 493-656: ts = 1697773439
# - Record 657-824: ts = 1697773440
# Batch published successfully. Number of records: 622
# - Record 1-124: ts = 1697773442
# - Record 125-248: ts = 1697773443
# - Record 249-372: ts = 1697773444
# - Record 373-496: ts = 1697773445
# - Record 497-622: ts = 1697773446
# Batch published successfully. Number of records: 990
# - Record 1-198: ts = 1697773449
# - Record 199-396: ts = 1697773450
# - Record 397-594: ts = 1697773451
# - Record 595-792: ts = 1697773452
# - Record 793-990: ts = 1697773453
# Batch published successfully. Number of records: 537
# - Record 1-107: ts = 1697773474
# - Record 108-214: ts = 1697773475
# - Record 215-321: ts = 1697773476
# - Record 322-428: ts = 1697773477
# - Record 429-537: ts = 1697773478
# Batch published successfully. Number of records: 706
# - Record 1-141: ts = 1697773480
# - Record 142-282: ts = 1697773481
# - Record 283-423: ts = 1697773482
# - Record 424-564: ts = 1697773483
# - Record 565-706: ts = 1697773484
# Batch published successfully. Number of records: 995
# - Record 1-199: ts = 1697773486
# - Record 200-398: ts = 1697773487
# - Record 399-597: ts = 1697773488
# - Record 598-796: ts = 1697773489
# - Record 797-995: ts = 1697773490
# Batch published successfully. Number of records: 799
# - Record 1-159: ts = 1697773493
# - Record 160-318: ts = 1697773494
# - Record 319-477: ts = 1697773495
# - Record 478-636: ts = 1697773496
# - Record 637-799: ts = 1697773497
# Batch published successfully. Number of records: 741
# - Record 1-148: ts = 1697773522
# - Record 149-296: ts = 1697773523
# - Record 297-444: ts = 1697773524
# - Record 445-592: ts = 1697773525
# - Record 593-741: ts = 1697773526
# Batch published successfully. Number of records: 573
# - Record 1-114: ts = 1697773528
# - Record 115-228: ts = 1697773529
# - Record 229-342: ts = 1697773530
# - Record 343-456: ts = 1697773531
# - Record 457-573: ts = 1697773532
# Batch published successfully. Number of records: 625
# - Record 1-125: ts = 1697773534
# - Record 126-250: ts = 1697773535
# - Record 251-375: ts = 1697773536
# - Record 376-500: ts = 1697773537
# - Record 501-625: ts = 1697773538
# Batch published successfully. Number of records: 982
# - Record 1-196: ts = 1697773540
# - Record 197-392: ts = 1697773541
# - Record 393-588: ts = 1697773542
# - Record 589-784: ts = 1697773543
# - Record 785-982: ts = 1697773544
# Batch published successfully. Number of records: 815
# - Record 1-163: ts = 1697773547
# - Record 164-326: ts = 1697773548
# - Record 327-489: ts = 1697773549
# - Record 490-652: ts = 1697773550
# - Record 653-815: ts = 1697773551
# Batch published successfully. Number of records: 682
# - Record 1-136: ts = 1697773553
# - Record 137-272: ts = 1697773554
# - Record 273-408: ts = 1697773555
# - Record 409-544: ts = 1697773556
# - Record 545-682: ts = 1697773557
# Batch published successfully. Number of records: 515
# - Record 1-103: ts = 1697773560
# - Record 104-206: ts = 1697773561
# - Record 207-309: ts = 1697773562
# - Record 310-412: ts = 1697773563
# - Record 413-515: ts = 1697773564
# Batch published successfully. Number of records: 979
# - Record 1-195: ts = 1697773566
# - Record 196-390: ts = 1697773567
# - Record 391-585: ts = 1697773568
# - Record 586-780: ts = 1697773569
# - Record 781-979: ts = 1697773570
# Batch published successfully. Number of records: 520
# - Record 1-104: ts = 1697773572
# - Record 105-208: ts = 1697773573
# - Record 209-312: ts = 1697773574
# - Record 313-416: ts = 1697773575
# - Record 417-520: ts = 1697773576
# Batch published successfully. Number of records: 553
# - Record 1-110: ts = 1697773579
# - Record 111-220: ts = 1697773580
# - Record 221-330: ts = 1697773581
# - Record 331-440: ts = 1697773582
# - Record 441-553: ts = 1697773583
# Batch published successfully. Number of records: 898
# - Record 1-179: ts = 1697773608
# - Record 180-358: ts = 1697773609
# - Record 359-537: ts = 1697773610
# - Record 538-716: ts = 1697773611
# - Record 717-898: ts = 1697773612
# Batch published successfully. Number of records: 592
# - Record 1-118: ts = 1697773614
# - Record 119-236: ts = 1697773615
# - Record 237-354: ts = 1697773616
# - Record 355-472: ts = 1697773617
# - Record 473-592: ts = 1697773618
# Batch published successfully. Number of records: 891
# - Record 1-178: ts = 1697773620
# - Record 179-356: ts = 1697773621
# - Record 357-534: ts = 1697773622
# - Record 535-712: ts = 1697773623
# - Record 713-891: ts = 1697773624
# Batch published successfully. Number of records: 802
# - Record 1-160: ts = 1697773627
# - Record 161-320: ts = 1697773628
# - Record 321-480: ts = 1697773629
# - Record 481-640: ts = 1697773630
# - Record 641-802: ts = 1697773631
